# %% [markdown]
# <a href="https://colab.research.google.com/github/swamyaswagat/leo-mec-handover-aware-optimization/blob/main/00_environment_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
# !mkdir notebooks
# !mkdir src
# !mkdir data
# !mkdir results
# !mkdir figures

# %%
# !ls
# Out:
# data  figures  notebooks  results  sample_data	src

# %%
# !pip install -q \
numpy \
pandas \
matplotlib \
torch \
gymnasium \
skyfield \
sgp4 \
scipy \
tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 370.4/370.4 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.7/235.7 kB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.3 MB/s eta 0:00:00

# %%
import numpy
import torch
import skyfield

print("Environment Ready")
# Out:
# Environment Ready

# %%
# %%writefile requirements.txt
#
# numpy
# pandas
# matplotlib
# torch
# gymnasium
# skyfield
# sgp4
# scipy
# tqdm
# Out:
# Writing requirements.txt

# %%
# !cat requirements.txt
# Out:
# numpy
# pandas
# matplotlib
# torch
# gymnasium
# skyfield
# sgp4
# scipy
# tqdm

# %%
import torch
import skyfield

print("Torch:", torch.__version__)
print("GPU:", torch.cuda.is_available())

if torch.cuda.is_available():
    print(torch.cuda.get_device_name(0))

print("Skyfield OK")
# Out:
# Torch: 2.11.0+cu128
# GPU: True
# Tesla T4
# Skyfield OK

# %%
torch.cuda.is_available()
# Out:
# True
